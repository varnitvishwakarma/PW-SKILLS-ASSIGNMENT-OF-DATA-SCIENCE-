# %%
##question 1 
# Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

from scipy import stats
import numpy as np 

confidence_level = 0.95
sample_mean = 50
sample_std = 5
sample_size = 500
sqr_sample=np.sqrt(sample_size)
standard_error = sample_std / sqr_sample

confidence_interval = stats.norm.interval(confidence_level, loc=sample_mean, scale=standard_error)

print("Confidence Interval:", confidence_interval)
# Out:
# Confidence Interval: (49.561738729711706, 50.438261270288294)

# %%
##question 2 
#Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 
#20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%brown. Use Python to perform the test with a significance level of 0.05.

significance_level =0.05
observed_data=[18,22,19,11,8,22]
expected_data=[20,20,20,10,10,20]
confidence_interval=0.95
dof=len(expected_data)-1

chi_square, p_value=stats.chisquare(observed_data,expected_data,significance_level)
critical = stats.chi2.ppf(1-significance_level,dof)

if chi_square > critical:
    print("we reject the null hypothsis")
else:
    print("we accept the null hypothsis")
# Out:
# we accept the null hypothsis

# %%
##question 3 
#Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following data:
groupA=[25,20,15]
groupB=[15,25,20]
significance_level=0.05

chi_square,p_value=stats.chisquare(groupA,groupB,significance_level)
print("chi_square_test:",chi_square)
print("p_value:",p_value)
# Out:
# chi_square_test: 8.916666666666668
# p_value: 0.010939790112284688

# %%
##question 4 
#A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% 
#confidence interval for the true proportion of individuals in the population who smoke.

import statsmodels.api as sm

sample_size = 500
observed_smokers = 60
confidence_level = 0.95

confidence_interval = sm.stats.proportion_confint(observed_smokers, sample_size, alpha=1 - confidence_level, method='wilson')

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (0.09437490012636912, 0.1514195986244106)

# %%
#Q5
#Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. Interpret the results.
confidence_level=0.90
mean=75
std=12
sample_size=400
sqrt_s_s=np.sqrt(sample_size)
sample_error=std/sqrt_s_s
confidence=stats.norm.interval(confidence_level,loc=sample_size,scale=sample_error)
print("90% confidence interval",confidence)
# Out:
# 90% confidence interval (399.0130878238291, 400.9869121761709)

# %%
##question 6 
#Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square 
#statistic of 15.
 

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

df = 10
chi_statistic = 15
x = np.linspace(0, 30, 500)  
pdf = stats.chi2.pdf(x, df)
plt.figure(figsize=(6, 3))
plt.plot(x, pdf, label=f"df = {df}")
x_shaded = np.linspace(0, chi_statistic, 500)
pdf_shaded = stats.chi2.pdf(x_shaded, df)
plt.fill_between(x_shaded, pdf_shaded, color='gray', alpha=0.5, label=f"Chi-square = {chi_statistic}")

plt.xlabel("Chi-Square Value")
plt.ylabel("Probability Density")
plt.title("Chi-Square Distribution")
plt.legend()
plt.grid(True)
plt.show()

# %%
##question 7 
#Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence 
#interval for the true proportion of people in the population who prefer Coke.
import statsmodels.api as sm

sample_size=1000
observed_values=520
confidence_interval=0.99
significance_value=0.01
confidence = sm.stats.proportion_confint(observed_values, sample_size, alpha=1 - confidence_level, method='wilson')
print("99% confidence interval",confidence)
# Out:
# 99% confidence interval (0.49399445666970754, 0.545897613600702)

# %%
##Q8. 
#A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. Conduct a chi-square goodness of
#fit test to determine if the observed frequencies match the expected frequencies of a fair coin. Use a significance level of 0.05.
import scipy.stats as stats

significance_level =0.05
sample_size=10
observed=[45,55]
determine=[50,50]
confidence=0.95
dof=len(determine)-1

chi_square,p_value=stats.chisquare(observed,determine,significance_level)
critical=stats.chi2.ppf(1-significance_level,dof)

if chi_square > critical :
    print("yes, its the observed value is match with determine ")
    
else:
    print("the observed value not match with detemine value")
# Out:
# the observed value not match with detemine value

# %%
##question 9 
#A study was conducted to determine if there is an association between smoking status (smoker or non-smoker) and lung cancer diagnosis 
#(yes or no). The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a 
#significant association between smoking status and lung cancer diagnosis.

significance_level=0.05
smoker=[60,140]
non_smoker=[30,170]
dof=len(smoker)-1
confidence=0.95

chi_square,p_value=stats.chisquare(smoker,non_smoker,significance_level)
critical=stats.chi2.ppf(1-significance_level,dof)

if chi_square > critical :
    print("we reject ")
else:
    print("accept")
# Out:
# we reject

# %%
#Q10. 
#A study was conducted to determine if the proportion of people who prefer milk chocolate, dark chocolate, or white chocolate is different 
#in the U.S. versus the U.K. A random sample of 500 people from the U.S. and a random sample of 500 people from the U.K. were surveyed. The 
#results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant
#association between chocolate preference and country of origin.


us=[200,150,150]
uk=[225,175,100]
significance_level=0.01
dof=len(uk)-1
confidence=0.99

chi,p=stats.chisquare(us,uk,significance_level)
critical=stats.chi2.ppf(1-significance_level,dof)

if chi > critical:
    print("we reject")
else:
    print("we accept")
# Out:
# we reject

# %%
##Q11.
#A random sample of 30 people was selected from a population with an unknown mean and standard deviation. The sample mean was found to be 72 and 
#the sample standard deviation was found to be 10.Conduct a hypothesis test to determine if the population mean is significantly different from 70. 
#Use a significance level of 0.05.

sample_size=30
mean=72
std=10
significance_level=0.05

# %%
import numpy as np
from scipy.stats import t

sample_size = 30
sample_mean = 72
sample_std = 10
population_mean = 70
confidence_level = 0.95  # 1 - significance level

# Calculate the t-statistic
t_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))

# Calculate the degrees of freedom
degrees_freedom = sample_size - 1

# Calculate the critical t-value for the given confidence level
alpha = 1 - confidence_level
critical_t_value = t.ppf(1 - alpha / 2, degrees_freedom)

print("T-statistic:", t_statistic)
print("Critical t-value:", critical_t_value)

if abs(t_statistic) > critical_t_value:
    print("Reject the null hypothesis: The population mean is significantly different from 70.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference from 70.")
# Out:
# T-statistic: 1.0954451150103321
# Critical t-value: 2.045229642132703
# Fail to reject the null hypothesis: There is no significant difference from 70.
